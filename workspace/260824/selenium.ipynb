# %%
# %pip install selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

driver=webdriver.Chrome() # Chrome 창이 뜬다

# %%
driver.get('https://www.naver.com') # naver.com이 열린다

# %%
driver.quit() # 종료

# %%
try:
    driver=webdriver.Chrome()
    ...
except:
    print('오류 처리')
finally:
    driver.quit()
