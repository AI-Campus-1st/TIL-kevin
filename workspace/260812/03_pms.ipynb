# %%
# %pip install pymysql python-dotenv
# Out:
# Requirement already satisfied: pymysql in c:\Users\kevin\anaconda3\envs\campus\Lib\site-packages (1.2.0)
# Requirement already satisfied: python-dotenv in c:\Users\kevin\anaconda3\envs\campus\Lib\site-packages (1.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# dotenv 불러오는 법
from dotenv import load_dotenv
load_dotenv()

# .env의 역할은 보안 정보들을 코드 외부에 관리하는 것
# 환경 변수 -> git에 올라가지 않게 관리 (.gitignore)
# Out:
# True

# %%
# 가져다 사용하는 법
import os
# os.environ['DB_HOST']
os.environ.get('DB_HOST', '테스트환경값')
# Out:
# '127.0.0.1'

# %%
type(os.environ) # dict처럼 사용
# Out:
# os._Environ

# %%
import pymysql

# mysql -u root -p
# mysql -h 127.0.0.1 -P 3306 -u root -ptest1234
conn = pymysql.connect(
    host=os.environ.get('DB_HOST', '127.0.0.1'), # 데이터베이스 서버(컴퓨터) 주소 (localhost, 127.0.0.1)
    port=int(os.environ.get('DB_PORT', '3306')),
    user=os.environ.get('DB_USER', 'analyst'),
    password=os.environ.get('DB_PASSWORD', ''),
    database=os.environ.get('DB_NAME', 'shop_db'),
    charset='utf8mb4'
)
# brute-force 완전탐색 공격
#   : 데이터베이스 서버 있는 것 확인 -> 비밀번호 무작위 조합 시도

DB_CONFIG = {
    'host': os.environ.get('DB_HOST', '127.0.0.1'),
    'port': int(os.environ.get('DB_PORT', '3306')),
    'user': os.environ.get('DB_USER', 'analyst'),
    'password': os.environ.get('DB_PASSWORD', ''),
    'database': os.environ.get('DB_NAME', 'shop_db'),
    'charset': 'utf8mb4',
    'autocommit': False,
}

# %%
from pymysql.cursors import DictCursor
conn = pymysql.connect(cursorclass=DictCursor, **DB_CONFIG)

# %%
# 가장 기본적인 SELECT 코드, tuple로 가져옴
with conn.cursor() as cur:
    # cur.execute('SELECT * FROM tb_customer LIMIT 2')
    cur.execute('SELECT VERSION()')
    result = cur.fetchone()
result
# Out:
# {'VERSION()': '10.6.27-MariaDB'}

# %%
# SQL Injection 공격
# SELECT * FROM tb_customer WHERE customer_name = '홍길동' OR 1=1;
sql = 'SELECT * FROM tb_customer WHERE customer_name = \'{}\''
with conn.cursor() as cur:
    name = '홍길동\' OR \'1\'=\'1'
    cur.execute(sql.format(name))
    rows = cur.fetchall()
rows
# Out:
# [{'customer_id': 1,
#   'customer_name': '홍길동',
#   'city': '인천',
#   'country': 'KR',
#   'signup_dt': datetime.date(2023, 1, 15),
#   'grade': 'GOLD'},
#  {'customer_id': 2,
#   'customer_name': '이연걸',
#   'city': '서울',
#   'country': 'KR',
#   'signup_dt': datetime.date(2023, 2, 3),
#   'grade': 'SILVER'},
#  {'customer_id': 3,
#   'customer_name': '이몽룡',
#   'city': '대전',
#   'country': 'KR',
#   'signup_dt': datetime.date(2023, 2, 20),
#   'grade': 'BRONZE'},
#  {'customer_id': 4,
#   'customer_name': '성춘향',
#   'city': '경기',
#   'country': 'KR',
#   'signup_dt': datetime.date(2023, 3, 11),
#   'grade': 'GOLD'},
#  {'customer_id': 5,
#   'customer_name': '김철수',
#   'city': '부산',
#   'country': 'KR',
#   'signup_dt': datetime.date(2023, 4, 5),
#   'grade': 'BRONZE'},
#  {'customer_id': 6,
#   'customer_name': '박영희',
#   'city': '서울',
#   'country': 'KR',
#   'signup_dt': datetime.date(2023, 5, 19),
#   'grade': 'SILVER'},
#  {'customer_id': 7,
#   'customer_name': 'Marie Dubois',
#   'city': 'Paris',
#   'country': 'FR',
#   'signup_dt': datetime.date(2023, 6, 1),
#   'grade': 'GOLD'},
#  {'customer_id': 8,
#   'customer_name': 'Laurent Petit',
#   'city': 'Lyon',
#   'country': 'FR',
#   'signup_dt': datetime.date(2023, 6, 22),
#   'grade': 'BRONZE'},
#  {'customer_id': 9,
#   'customer_name': 'Carlos Ruiz',
#   'city': 'Madrid',
#   'country': 'ES',
#   'signup_dt': datetime.date(2023, 7, 8),
#   'grade': 'SILVER'},
#  {'customer_id': 10,
#   'customer_name': 'Yuki Tanaka',
#   'city': 'Tokyo',
#   'country': 'JP',
#   'signup_dt': datetime.date(2023, 8, 14),
#   'grade': 'BRONZE'},
#  {'customer_id': 11,
#   'customer_name': 'Sora Kim',
#   'city': 'Seoul',
#   'country': 'KR',
#   'signup_dt': datetime.date(2023, 9, 2),
#   'grade': None},
#  {'customer_id': 12,
#   'customer_name': 'John Smith',
#   'city': 'New York',
#   'country': 'US',
#   'signup_dt': datetime.date(2023, 10, 27),
#   'grade': 'GOLD'},
#  {'customer_id': 13,
#   'customer_name': '최민수',
#   'city': '광주',
#   'country': 'KR',
#   'signup_dt': datetime.date(2023, 11, 5),
#   'grade': 'SILVER'},
#  {'customer_id': 14,
#   'customer_name': '정다은',
#   'city': '서울',
#   'country': 'KR',
#   'signup_dt': datetime.date(2023, 11, 19),
#   'grade': 'GOLD'},
#  {'customer_id': 15,
#   'customer_name': '오세훈',
#   'city': '인천',
#   'country': 'KR',
#   'signup_dt': datetime.date(2023, 12, 1),
#   'grade': 'BRONZE'},
#  {'customer_id': 16,
#   'customer_name': '한지민',
#   'city': '대구',
#   'country': 'KR',
#   'signup_dt': datetime.date(2023, 12, 14),
#   'grade': None},
#  {'customer_id': 17,
#   'customer_name': '강동원',
#   'city': '부산',
#   'country': 'KR',
#   'signup_dt': datetime.date(2024, 1, 8),
#   'grade': 'SILVER'},
#  {'customer_id': 18,
#   'customer_name': 'Sophie Martin',
#   'city': 'Paris',
#   'country': 'FR',
#   'signup_dt': datetime.date(2024, 1, 21),
#   'grade': 'SILVER'},
#  {'customer_id': 19,
#   'customer_name': 'Diego Torres',
#   'city': 'Barcelona',
#   'country': 'ES',
#   'signup_dt': datetime.date(2024, 2, 2),
#   'grade': 'BRONZE'},
#  {'customer_id': 20,
#   'customer_name': 'Hana Sato',
#   'city': 'Osaka',
#   'country': 'JP',
#   'signup_dt': datetime.date(2024, 2, 17),
#   'grade': 'GOLD'},
#  {'customer_id': 21,
#   'customer_name': 'Emma Wilson',
#   'city': 'London',
#   'country': 'GB',
#   'signup_dt': datetime.date(2024, 3, 4),
#   'grade': 'SILVER'},
#  {'customer_id': 22,
#   'customer_name': 'Liu Wei',
#   'city': 'Shanghai',
#   'country': 'CN',
#   'signup_dt': datetime.date(2024, 3, 18),
#   'grade': 'BRONZE'},
#  {'customer_id': 23,
#   'customer_name': 'Anna Muller',
#   'city': 'Berlin',
#   'country': 'DE',
#   'signup_dt': datetime.date(2024, 4, 1),
#   'grade': 'GOLD'},
#  {'customer_id': 24,
#   'customer_name': '서지우',
#   'city': '서울',
#   'country': 'KR',
#   'signup_dt': datetime.date(2024, 4, 22),
#   'grade': 'BRONZE'}]

# %%
sql = 'SELECT * FROM tb_customer WHERE customer_name = \'{}\''
name = '홍길동\' OR \'1\'=\'1'
sql.format(name)
# Out:
# "SELECT * FROM tb_customer WHERE customer_name = '홍길동' OR '1'='1'"

# %%
sql = 'SELECT * FROM tb_customer WHERE customer_name IN (%s, %s)'
with conn.cursor() as cur:
    # name = '홍길동 OR 1=1'
    name = '홍길동'
    name2 = '이몽룡'
    cur.execute(sql, (name, name2))
    rows = cur.fetchall()
rows
# Out:
# [{'customer_id': 1,
#   'customer_name': '홍길동',
#   'city': '인천',
#   'country': 'KR',
#   'signup_dt': datetime.date(2023, 1, 15),
#   'grade': 'GOLD'},
#  {'customer_id': 3,
#   'customer_name': '이몽룡',
#   'city': '대전',
#   'country': 'KR',
#   'signup_dt': datetime.date(2023, 2, 20),
#   'grade': 'BRONZE'}]

# %%
sql = 'SELECT * FROM tb_customer'
with conn.cursor() as cur:
    cur.execute(sql, ())
    for row in cur:
        print(row)

# %% [markdown]
# ### 실습 CRUD

# %%
# 코드 정리
import os
from dotenv import load_dotenv
import pymysql
from pymysql.cursors import DictCursor

load_dotenv()

DB_CONFIG = {
    'host': os.environ.get('DB_HOST', '127.0.0.1'),
    'port': int(os.environ.get('DB_PORT', '3306')),
    'user': os.environ.get('DB_USER', 'analyst'),
    'password': os.environ.get('DB_PASSWORD', ''),
    'database': os.environ.get('DB_NAME', 'shop_db'),
    'charset': 'utf8mb4',
    'autocommit': False,
}

conn = pymysql.connect(cursorclass=DictCursor, **DB_CONFIG)

# %%
# 01 테이블생성 id · name · email · phone · major

# %%
sql = """
CREATE TABLE tb_student(
    id INT NOT NULL AUTO_INCREMENT,
    name VARCHAR(32) NOT NULL,
    email VARCHAR(255) NOT NULL,
    phone VARCHAR(32),
    major VARCHAR(32),
    PRIMARY KEY (id)
);
"""

with conn.cursor() as cur:
    cur.execute(sql) # InterfaceError (0, ) -> 연결 끊김 / 연결 후 재시도
    # conn.commit()
# conn.close()

# %%
# 02 한건 INSERT lastrowid 확인

# %%
sql = """
INSERT INTO tb_student(name, email, phone, major)
    VALUES (%s, %s, %s, %s);
"""
with conn.cursor() as cur:
    # arg
    cur.execute(sql, ('홍길동', 'hong@gil.dong', '02-111-233', '성학과'))
    conn.commit()

# %%
# cur.execute('SELECT VERSION();')

# %%
cur.lastrowid
# Out:
# 2

# %%
# 03 네건 동시 INSERT executemany

# %%
sql = """
INSERT INTO tb_student(name, email, phone, major)
    VALUES (%s, %s, %s, %s);
"""
with conn.cursor() as cur:
    # args
    cur.executemany(sql, [
        ('이연걸', 'hong@gil.dong', '02-111-233', '성학과'),
        ('이몽룡', 'hong@gil.dong', '02-111-233', '성학과'),
        ('성춘향', 'hong@gil.dong', '02-111-233', '성학과'),
        ('김철수', 'hong@gil.dong', '02-111-233', '성학과'),
    ])
    conn.commit()

# %%
# 04 전체 조회 DictCursor로 받아 출력

# %%
sql = 'SELECT * FROM tb_student;'

with conn.cursor() as cur:
    cur.execute(sql)
    rows = cur.fetchall()
rows

# %%
# 05 이메일수정 파라미터 바인딩 사용

# %%
sql = """
UPDATE tb_student
SET email = %s
WHERE name = %s
"""

email = 'lee@mong.ry'
name = '이몽룡'

with conn.cursor() as cur:
    cur.execute(sql, (email, name))
    conn.commit()

# %%
cur.rowcount
# Out:
# 1

# %%
# 06 한명삭제 rowcount 확인

# %%
sql = 'DELETE FROM tb_student WHERE name=%s'

name = '김철수'
with conn.cursor() as cur:
    cur.execute(sql, (name,))
    conn.commit()

cur.rowcount
# Out:
# 1

# %%
conn.close()

# %%
"""
CREATE TABLE tb_account(
    acc_no VARCHAR(16) NOT NULL,
    balance INT NOT NULL,
    owner VARCHAR(32) NOT NULL,
    PRIMARY KEY (acc_no)
);
"""

"""
INSERT INTO tb_account(acc_no, owner, balance)
    VALUES ('A-001', '홍길동', 300000);
"""

# %%
with conn.cursor() as cur:
    cur.execute("UPDATE tb_account SET balance = 999999 where acc_no= 'A-001'")
    cur.execute("SELECT balance FROM tb_account where acc_no= 'A-001'")
    print(cur.fetchone()) # 999999로 보입니다
conn.close()
# Out:
# {'balance': 999999}

# %%
import time
def _run(sql):
    # conn = get_connection()
    st = time.time()
    try:
        with conn.cursor() as cur:
            cur.execute(sql)

        print('총 소요시간:', time.time() - st)

        conn.commit()
    except pymysql.err.OperationalError as e:
        print(f'[트랜잭션 에러]: {e}, 롤백합니다')
        conn.rollback()
    finally:
        conn.close()

_run('SELECT * FROM tb_student')
# Out:
# 총 소요시간: 0.0005066394805908203

# %%
import math
math.ceil(10003/1000)
# Out:
# 11

# %%
sql = 'INSERT INTO tb_account(acc_no, balance, owner) VALUES (%s, %s, %s)'
N = 10000
chunk_size = 1000

# 10003
# -> 11번

import time

st = time.time()
with conn.cursor() as cur:
    args = [(f'A-{str(i).zfill(5)}', 1000, '홍길동') for i in range(1, 10000)]
    # execute + commit 1만번
    for arg in args:
        cur.executemany(sql, args)
        conn.commit()
        
    # execute + commit 1번
    args = [(f'A-{str(i).zfill(5)}', 1000, '홍길동') for i in range(10001, 20000)]
    for arg in args:
        cur.executemany(sql, args)
    conn.commit()

    # excute_many
    args = [(f'A-{str(i).zfill(5)}', 1000, '홍길동') for i in range(20001, 30000)]
    cur.executemany(sql, args)
    conn.commit()

    # 청크
    args = [(f'A-{str(i).zfill(5)}', 1000, '홍길동') for i in range(30001, 40000)]
    for i in range(N//chunk_size):
        cur.executemany(sql, args[i*chunk_size:(i+1)*chunk_size])
        conn.commit()
        
'총 소요시간' + str(time.time() - st)

# 5.073619604110718 execute + commit
# 0.716788291931152 execute + 1회 commit
# 0.063856601715087 executemany + commit
# 0.078795909881591 청크 executemany + commit
# Out:
# '총 소요시간0.0787959098815918'

# %%
table = 'tb_customer'
cols = ['customer_name', 'email']
values = ('홍길동', 'hong@gil.dong')

sql = f"""
    INSERT INTO {table}({','.join(cols)})
        VALUES ({','.join(['%s']*len(values))})
"""
print(sql)

_run(sql, args=values)
# Out:
#     INSERT INTO tb_customer(customer_name,email)
#         VALUES (%s,%s)

# %%
','.join(['%s']*len(values))
# Out:
# '%s,%s'

# %%
table = 'tb_student'
cols = ['*']
sql = f"""
        SELECT {','.join(cols)}
        FROM {table}
        """

# %%
print(sql)
# Out:
#         SELECT *
#         FROM tb_student
