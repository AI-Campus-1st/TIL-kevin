# %% [markdown]
# <p style="font-size: 33px; font-weight: 700; margin-bottom: 3rem">에러 & 예외 처리</p>
#
# - 에러(Error)
# - 예외 처리(Exception Handling)
#
# [파이썬 문서](https://docs.python.org/ko/3/library/exceptions.html#exception-hierarchy)

# %% [markdown]
# # 에러(Error)
# 발생할 수 있는 에러의 종류를 확인해봅시다.

# %% [markdown]
# ## 문법 에러(Syntax Error)
#
# > 문법 에러가 있는 프로그램은 실행되지 않습니다.
#
# * 에러 발생 시 `SyntaxError`라는 키워드와 함께, 에러의 상세 내용을 보여줍니다.
#
#
# * `파일이름`과 `줄번호`, `^` 문자를 통해 파이썬이 코드를 읽어 들일 때(`parser`) 문제가 발생한 위치를 표현합니다.
#
#
# * `parser` 는 줄에서 에러가 감지된 가장 앞의 위치를 가리키는 캐럿(caret)기호(`^`)를 표시합니다.

# %%
# 조건문을 통해 문법 에러를 발생시켜봅시다.

# 아래 코드는 else문 뒤에 콜론이 누락되어 있습니다.
# 코드를 실행시켜보고 invalid syntax 오류를 확인해보세요.

# %%
if True:
    print('참')
else
    print('거짓')
# Out:
#   Cell In[19], line 3
#     else
#         ^
# SyntaxError: expected ':'

# %%
# print문을 통해 다른 오류를 발생시켜봅시다.

# 아래 코드는 닫는 따옴표가 누락되어 있습니다.
# 코드를 실행시켜보고 EOL 오류(따옴표 오류)를 확인해봅시다.

# %%
print('hi)
# Out:
#   Cell In[6], line 1
#     print('hi)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
# EOF 에러(괄호 닫기 오류)도 보게됩니다.

# %%
print('hi'
# Out:
#   Cell In[7], line 1
#     print('hi'
#               ^
# SyntaxError: incomplete input

# %%
name = 'jason'
result = {'amount': 1000}
# 3.9버전에서는 오류
print(f'안녕하세요, 저는 {name} 입니다. {result['amount']}')
# Out:
# 안녕하세요, 저는 jason 입니다. 1000

# %%
# 정확한 위치를 지정하지 않을 수도 있으므로 지정된 위치 전후를 모두 확인해야합니다.

# 아래 코드의 조건문에는 콜론이 누락되어 있습니다.
# 코드를 실행시켜보고 문법 오류를 확인해보세요.

# %%
if True print('참')
# Out:
#   Cell In[16], line 1
#     if True print('참')
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 예외(Exception)
#
# > 실행 도중 예상하지 못한 상황(exception)을 맞이하면, 프로그램 실행을 멈춥니다.
#
# * 문법적으로는 옳지만, 실행시 발생하는 에러입니다.
#
#
# * *아래 제시된 모든 에러는 `Exception`을 상속받아 이뤄진다.*

# %%
# class Exception(BaseException):

#     def __init__(self, msg):
#         self.msg = msg

#     def __str__(self):
#         return self.msg

# class ValueError(Exception):
#     pass

class MyOwnError(Exception):
    pass

raise MyOwnError('내 에러')
# Out:
# ---------------------------------------------------------------------------
# MyOwnError                                Traceback (most recent call last)
# Cell In[4], line 15
#      11
#      12 class MyOwnError(Exception):
#      13     pass
#      14
# ---> 15 raise MyOwnError('내 에러')
#
# MyOwnError: 내 에러

# %%
# ZeroDivisionError를 확인해봅시다.

# %%
# 파이썬에서는 어떤 수를 0으로 나누게 되면 에러가 발생합니다
# 어떤 수를 0으로 나누는 코드를 작성해보고 오류를 확인해보세요.
3 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 # 파이썬에서는 어떤 수를 0으로 나누게 되면 에러가 발생합니다
#       2 # 어떤 수를 0으로 나누는 코드를 작성해보고 오류를 확인해보세요.
# ----> 3 3 / 0
#
# ZeroDivisionError: division by zero

# %%
# NameError를 확인해봅시다.

# %%
# 지역 혹은 전역 이름 공간내에서 유효하지 않는 이름은 사용할 수 없습니다.
# 즉, 어느 곳에서도 정의되지 않은 변수를 호출 하였을 경우 에러가 발생합니다.
# abc라는 변수를 print로 출력해보고 오류를 확인해보세요.
print(abc) # 오타
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 # 지역 혹은 전역 이름 공간내에서 유효하지 않는 이름은 사용할 수 없습니다.
#       2 # 즉, 어느 곳에서도 정의되지 않은 변수를 호출 하였을 경우 에러가 발생합니다.
#       3 # abc라는 변수를 print로 출력해보고 오류를 확인해보세요.
# ----> 4 print(abc)
#
# NameError: name 'abc' is not defined

# %%
# TypeError를 확인해봅시다.

# %%
# 자료형이 올바르지 못한 경우에도 에러가 발생합니다.
# 숫자 1과 문자 1을 더하는 코드를 작성해보고 오류를 확인해보세요.
1 + '1'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # 자료형이 올바르지 못한 경우에도 에러가 발생합니다.
#       2 # 숫자 1과 문자 1을 더하는 코드를 작성해보고 오류를 확인해보세요.
# ----> 3 1 + '1'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# 함수 호출과정에서도 TypeError 오류가 발생할 수 있습니다.
# round 함수는 어떤 수를 반올림해주는 내장 함수입니다.
# round 함수에 숫자가 아닌 문자를 넣어보고 발생하는 오류를 확인해봅시다.

# %%
round('1.5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 round('1.5')
#
# TypeError: type str doesn't define __round__ method

# %%
# 함수호출 과정에서 다양한 오류를 확인할 수 있습니다. 
# (1) 필수 매개변수가 누락된 경우를 살펴봅시다.

# %%
# 내장 random 모듈을 불러오세요.
# random.sample() 함수는 2개의 매개변수를 받도록 정의되어 있습니다.
# random.sample() 함수에 숫자 3개가 담긴 리스트만 넣고 호출해보세요.
# 그리고 매개변수가 누락되어 발생하는 오류를 확인해보세요.
import random

# result = {n: 0 for n in [15, 38, 60]}
# for i in range(int(1e6)):
#     num = random.sample([15, 38, 60], 1)[0]
#     result[num] += 1

random.sample([15, 38, 60])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 12
#       8 # for i in range(int(1e6)):
#       9 #     num = random.sample([15, 38, 60], 1)[0]
#      10 #     result[num] += 1
#      11
# ---> 12 random.sample([15, 38, 60])
#
# TypeError: Random.sample() missing 1 required positional argument: 'k'

# %%
# 함수호출 과정에서 다양한 오류를 확인할 수 있습니다. 
# (2) 매개변수 개수가 초과해서 들어온 경우를 살펴봅시다.

# %%
# random.choice() 함수는 하나의 매개변수만 받도록 정의되어 있습니다.
# 숫자 3개가 담긴 리스트와, 숫자 6을 넣고 호출해보세요.
# 그리고 매개변수가 초가되어 발생하는 오류를 확인해보세요.
# ====
random.choice([1, 2, 3], 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[119], line 5
#       1 # random.choice() 함수는 하나의 매개변수만 받도록 정의되어 있습니다.
#       2 # 숫자 3개가 담긴 리스트와, 숫자 6을 넣고 호출해보세요.
#       3 # 그리고 매개변수가 초가되어 발생하는 오류를 확인해보세요.
#       4 # ====
# ----> 5 random.choice([1, 2, 3], 3)
#
# TypeError: Random.choice() takes 2 positional arguments but 3 were given

# %%
def abc():
    ...

type(abc)
# Out:
# function

# %%
type(random.choice)
# Out:
# method

# %%
# ValueError를 확인해봅시다.

# %%
# 자료형은 올바르나 값이 적절하지 않은 경우를 살펴봅시다.
# int()는 정수가 아닌 값을 받았을 경우 에러가 발생합니다.
# int() 안에 문자 3.5를 넣고 호출한 뒤 발생하는 오류를 확인해보세요.
int('3.5')

# # 잔액부족할때 에러
# class BalanceIsNotSufficient(Exception):
#     ...
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[124], line 4
#       1 # 자료형은 올바르나 값이 적절하지 않은 경우를 살펴봅시다.
#       2 # int()는 정수가 아닌 값을 받았을 경우 에러가 발생합니다.
#       3 # int() 안에 문자 3.5를 넣고 호출한 뒤 발생하는 오류를 확인해보세요.
# ----> 4 int('3.5')
#
# ValueError: invalid literal for int() with base 10: '3.5'

# %%
# ValueError를 확인해봅시다.

# %%
# 존재하지 않는 값을 찾고자 할 경우
# index()는 리스트에서 찾고자 하는 값의 인덱스를 반환합니다.
# numbers 리스트에 없는 값인 3을 찾게 되면 에러가 발생합니다.
# 아래 코드를 실행시킨 뒤 발생하는 오류를 확인해보세요.

numbers = [1, 2]
numbers.index(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[125], line 7
#       3 # numbers 리스트에 없는 값인 3을 찾게 되면 에러가 발생합니다.
#       4 # 아래 코드를 실행시킨 뒤 발생하는 오류를 확인해보세요.
#       5
#       6 numbers = [1, 2]
# ----> 7 numbers.index(3)
#
# ValueError: 3 is not in list

# %%
# IndexError를 확인해봅시다.

# %%
# 존재하지 않는 index로 조회할 경우
# 비어있는 리스트는 어떤 인덱스 값으로든 접근할 수 없습니다.
# 비어있는 empty_list를 -1 인덱스로 접근했을 때 발생하는 오류를 확인해보세요.

empty_list = []
empty_list[-1]
# 1. 인덱스가 리스트 길이(범위)를 벗어났는지
# 2. 리스트가 비어있지는 않은지
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[132], line 6
#       2 # 비어있는 리스트는 어떤 인덱스 값으로든 접근할 수 없습니다.
#       3 # 비어있는 empty_list를 -1 인덱스로 접근했을 때 발생하는 오류를 확인해보세요.
#       4
#       5 empty_list = []
# ----> 6 empty_list[-1]
#
# IndexError: list index out of range

# %%
# KeyError를 확인해봅시다.

# %%
my_dict = {}
my_dict[ [1] ] = 3 # TypeError
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[135], line 2
#       1 my_dict = {}
# ----> 2 my_dict[ [1] ] = 3 # TypeError
#
# TypeError: unhashable type: 'list'

# %%
# 딕셔너리에서 Key가 없는 경우 

# 딕셔너리는 존재하지 않는 Key로 접근하게 되면 오류가 발생합니다.
# 아래 songs라는 딕셔너리에는 'sia'라는 Key만 존재하며,
# 'queen'이라는 키는 존재하지 않습니다.
# 코드를 실행시켜보고 발생하는 오류를 확인해보세요.

songs = {'sia': 'candy cane lane'}
songs['queen']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[136], line 9
#       5 # 'queen'이라는 키는 존재하지 않습니다.
#       6 # 코드를 실행시켜보고 발생하는 오류를 확인해보세요.
#       7
#       8 songs = {'sia': 'candy cane lane'}
# ----> 9 songs['queen']
#
# KeyError: 'queen'

# %%
# ModuleNotFoundError를 확인해봅시다.

# %%
# 모듈을 찾을 수 없는 경우 

# 파이썬에 존재하지 않는 모듈인 "reque"라는 이름의 모듈을 불러와봅시다(import).
# 그리고 발생하는 오류를 확인해보세요.
import reque
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[137], line 5
#       1 # 모듈을 찾을 수 없는 경우
#       2
#       3 # 파이썬에 존재하지 않는 모듈인 "reque"라는 이름의 모듈을 불러와봅시다(import).
#       4 # 그리고 발생하는 오류를 확인해보세요.
# ----> 5 import reque
#
# ModuleNotFoundError: No module named 'reque'

# %%
import mod.test2

# 내가 작성했을 때 발생한다?
# 경로 정보를 잘못 준 경우

# 다른사람 패키지 가져와서 설치했을 때 발생 (pip)
# 오타
# 다른 가상환경에 설치한 경우 (내 가상환경에 설치가 안 된 경우)
# 내 가상환경의 패키지 목록이 최신화가 안 된 경우

# %%
# ImportError를 확인해봅시다.

# %%
# 모듈을 찾았으나 가져오는 과정에서 실패하는 경우 (존재하지 않는 클래스/함수 호출)

# 파이썬 내장 random 모듈은 존재하나 그 안에 "sampl"이라는 함수는 존재하지 않습니다.
# random 모듈을 불러와서 "sampl"이라는 함수를 불러와보고, 발생하는 오류를 확인해보세요.
import random
random.sampl([1, 2, 3], 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 6
#       2
#       3 # 파이썬 내장 random 모듈은 존재하나 그 안에 "sampl"이라는 함수는 존재하지 않습니다.
#       4 # random 모듈을 불러와서 "sampl"이라는 함수를 불러와보고, 발생하는 오류를 확인해보세요.
#       5 import random
# ----> 6 random.sampl([1, 2, 3], 1)
#
# AttributeError: module 'random' has no attribute 'sampl'

# %%
# AttributeError
class a:
    ...

b = a()

b.aa

# %%
# KeyboardInterrupt를 확인해봅시다.

# %%
# 주피터 노트북에서는 정지 버튼이지만, 실제로 우리가 돌릴 때는 ctrl+c를 통해 종료하였을 때 발생합니다.
# 무한 반복되는 while문을 실행시켜보고, 정지시켜보세요.
# 그리고 발생하는 오류를 확인해보세요.

while 1:
    print('hello')

# %% [markdown]
# # 예외 처리(Exception Handling)
#
# ##  `try` & `except`
# `try` 문을 이용하여 예외 처리를 할 수 있습니다.
#
# ---
#
# ### 기초 문법
#
# ```python
# try:
#     <코드 블럭 1>
# except (예외):
#     <코드 블럭 2>
# ```
#
# * `try` 아래의 코드블락(code block)이 실행됩니다.
#
# * 예외가 발생되지 않으면, **`except`없이 실행이 종료 됩니다.**
#
# * 예외가 발생하면, **남은 부분을 수행하지 않고**, `except`가 실행됩니다.

# %%
# 사용자로부터 값을 받아 정수로 변환하여 출력해봅시다.

# %%
# input() 함수를 이용하여 사용자로부터 입력을 받은 뒤
# 해당 값을 정수로 변환하여 출력해보세요.

num = int( input() )
print(num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       1 # input() 함수를 이용하여 사용자로부터 입력을 받은 뒤
#       2 # 해당 값을 정수로 변환하여 출력해보세요.
#       3
# ----> 4 num = int( input() )
#       5 print(num)
#
# ValueError: invalid literal for int() with base 10: '5 3'

# %%
# 사용자가 문자열을 넣어 해당 오류(ValueError)가 발생하면, 숫자를 입력하라고 출력해봅시다.
# 위에서 배운 try-except 구문을 활용해보세요.

# %%
try:
    num = int( input() )
    print(num)
except ValueError as e:
    print('숫자를 입력해주세요.')
# Out:
# 숫자를 입력해주세요.

# %% [markdown]
# ### 복수의 예외 처리
#
# 하나 이상의 예외를 모두 처리할 수 있습니다.
#
# 괄호가 있는 튜플로 여러 개의 예외를 지정할 수 있습니다.
#
# ---
#
# **활용법**
#
# ```python
# try:
#     <코드 블럭 1>
# except (예외1, 예외2):
#     <코드 블럭 2>
#
#
# try:
#     <코드 블럭 1>
# except 예외1:
#     <코드 블럭 2>
# except 예외2:
#     <코드 블럭 3>
# ```

# %%
# 숫자 100을 사용자가 입력한 값으로 나눈 후 출력하는 코드를 작성해봅시다.

# input() 함수를 이용하여 사용자로부터 입력을 받으세요.
# 해당 값을 정수로 변환한 뒤, 숫자 100을 입력받은 값으로 나누는 코드를 작성해보세요.

# %%
num = int( input() )
print(100 / num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 num = int( input() )
#       2 print(100 / num)
#
# ValueError: invalid literal for int() with base 10: '12 56'

# %%
# 문자열일때와 0일때의 경우를 모두 처리를 해봅시다.

# 어떤 값을 숫자가 아닌 값으로 나눌 때 발생하는 에러는 ValueError입니다.
# 어떤 값을 0으로 나눌 때 발생하는 에러는 ZeroDivisionError입니다.
# try-except 구문을 활용하여 위의 두 오류를 처리해보세요.

# %%
try:
    num = int( input() )
    print(100 / num)
except (ValueError, ZeroDivisionError):
    print('숫자를 입력해주세요.')
# Out:
# 숫자를 입력해주세요.

# %%
# 각각 다른 오류를 출력할 수 있습니다.
# 여러 개의 except 구문을 활용해보세요.
# (ValueError, ZeroDivisionError)

# %%
try:
    num = int( input() )
    print(100 / num)
except ValueError:
    print('숫자를 입력해주세요.')
except ZeroDivisionError:
    print('숫자는 0으로 나눌 수 없습니다.')
# Out:
# 숫자는 0으로 나눌 수 없습니다.

# %% [markdown]
# - 여기서 중요한 내용은 **에러가 순차적으로 수행됨**으로, 가장 작은 범주부터 시작해야 합니다.

# %%
# Exception은 가장 큰 범주의 에러로써 모든 에러를 처리할 수 있습니다.
# 따라서 아래 코드는 숫자가 아닌 값을 넣었을 때 순차적으로 먼저 적힌 Exception 에러가 발생합니다.
# 코드를 실행하고 결과를 확인해보세요.

try:
    num = input('값을 입력하시오: ')
    100/int(num)
except Exception: # Exception 은 가장 큰 범주
    print('모르겠지만 에러야')
except ValueError:
    print('숫자를 넣어')
# Out:
# 모르겠지만 에러야

# %% [markdown]
# ### `else`
#
# * 에러가 발생하지 않는 경우 수행되는 문장은 `else`를 이용합니다.
# * 모든 except 절 뒤에와야 합니다.
# * try 절이 예외를 일으키지 않을 때 실행되어야만 하는 코드에 적절합니다.
#
# ---
#
# **활용법**
#
# ```python
# try:
#     <코드 블럭 1>
# except 예외:
#     <코드 블럭 2>
# else:
#     <코드 블럭 3>
# ```

# %%
# else를 사용해봅시다.

# try 구문에서 numbers라는 이름의 리스트에 숫자 3개를 저장하세요.
# 그리고 존재하지 않는 인덱스의 값을 가져와서 number 변수에 저장하세요.
# (이 때, 존재하지 않는 인덱스를 참고하는 경우 IndexError가 발생하게 됩니다.)
# except 구문에서 IndexError가 발생할 경우 '오류 발생'이라는 메세지를 출력하세요.
# 마지막으로 else 구문을 활용하여 number * 100을 출력해보세요.

# %%
try:
    numbers = [1, 2, 3]
    number = numbers[2]
except IndexError:
    print('오류 발생')
else:
    print(number * 100)
# Out:
# 300

# %%
try:
    numbers = [1, 2, 3]
    number = numbers[100]
except IndexError:
    print('오류 발생')
else:
    print(number * 100)
# Out:
# 오류 발생

# %% [markdown]
# ### `finally`
#
# * 반드시 수행해야하는 문장은 `finally`를 활용합니다.
# * 즉, 모든 상황에 실행되어야만 하는 코드를 정의하는데 활용합니다.
# * 예외의 발생 여부과 관계없이 try 문을 떠날 때 항상 실행합니다.
#
# ---
#
# **활용법**
#
# ```python
# try:
#     <코드 블럭 1>
# except 예외:
#     <코드 블럭 2>
# finally:
#     <코드 블럭 3>
# ```

# %%
# finally를 사용해봅시다.

# %%
# 아래 코드에서 finally 구문을 활용하여 '성적 파일을 종료합니다'라는 메세지를 출력해보세요.

try:
    print('성적 파일을 읽어옵니다.')
    data = {'python': 'A+'}
    data['java']
except KeyError as err:
    print(f'{err}는 딕셔너리에 없는 키입니다.')
finally:
    print('성적 파일을 닫습니다.')
# Out:
# 성적 파일을 읽어옵니다.
# 'java'는 딕셔너리에 없는 키입니다.
# 성적 파일을 닫습니다.

# %%
try:
    # 파일을 연다. (자원 회득)
    f = open('data.csv', 'r')
    lines = f.readlines()
    lines[500]
except IndexError:
    print('파일 길이가 맞지 않습니다.')
finally:
    # 파일을 닫는다. (자원 릴리즈)
    f.close()
# Out:
# 파일 길이가 맞지 않습니다.

# %% [markdown]
# ### 에러 메시지 처리  `as`
#
# `as` 키워드를 활용하여 에러 메시지를 보여줄 수도 있습니다.
#
# ---
#
# **활용법**
#
# ```python
# try:
#     <코드 블럭 1>
# except 예외 as err:
#     <코드 블럭 2>
# ```

# %%
# except 구문에서 발생하는 에러 메세지를 코드 블럭에 넘겨줄 수도 있습니다.

# %%
# 아래 코드에서 as를 활용하여 에러 메세지를 그 아래 코드 블럭에 넘겨보세요.
# 그리고 as로 명명한 에러 메세지를 print를 이용하여 출력해보세요.

try:
    empty_list = []
    print(empty_list[-1])
except IndexError:
    # 여기에 코드를 작성하세요

# %%
# 

try:
    empty_list = []
    print(empty_list[-1])
except IndexError as err:
    print(f'{err}, 오류가 발생했습니다.')
# Out:
# list index out of range, 오류가 발생했습니다.

# %% [markdown]
# ## 예외 발생 시키기(Exception Raising)

# %% [markdown]
# ### `raise`
# `raise`를 통해 예외를 강제로 발생시킬 수 있습니다.
#
# ---
#
# **활용법**
#
# ```python
# raise <에러>('메시지')
# ```

# %%
# raise를 사용해봅시다.

# %%
# raise만 작성한 뒤 실행시켜봅시다.
# 아래 코드를 실행시켜보고 결과를 확인하세요.

raise
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[39], line 4
#       1 # raise만 작성한 뒤 실행시켜봅시다.
#       2 # 아래 코드를 실행시켜보고 결과를 확인하세요.
#       3
# ----> 4 raise
#
# RuntimeError: No active exception to reraise

# %%
# 이번에는 ValueError() 오류를 raise해봅시다.
# 아래 코드를 실행시켜보고 결과를 확인하세요.

raise ValueError('잔액 부족')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 4
#       1 # 이번에는 ValueError() 오류를 raise해봅시다.
#       2 # 아래 코드를 실행시켜보고 결과를 확인하세요.
#       3
# ----> 4 raise ValueError('잔액 부족')
#
# ValueError: 잔액 부족

# %% [markdown]
# ### [연습] `raise` 예외 발생시키기
#
# > 리스트를 받아 평균을 반환하는 `def avg(scores)`를 작성하세요.
#
# ---
#
# - scores의 길이가 0인 경우 `Exception`과 메시지를 발생시키세요.
#     - *예) Exception: 학생이 없습니다.*
#
# - 정상적인 경우에는 결과를 return합니다.

# %%
# 아래에 코드를 작성하세요.

# %%
def avg(scores):
    if len(scores) == 0:
        raise Exception('학생이 없습니다.')
    return sum(scores)/len(scores)

# %%
# 해당 코드를 통해 올바른 결과가 나오는지 확인하세요.
avg([])
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 # 해당 코드를 통해 올바른 결과가 나오는지 확인하세요.
# ----> 2 avg([])
#
# Cell In[41], line 3, in avg(scores)
#       1 def avg(scores):
#       2     if len(scores) == 0:
# ----> 3         raise Exception('학생이 없습니다.')
#       4     return sum(scores)/len(scores)
#
# Exception: 학생이 없습니다.

# %% [markdown]
# ### `assert`
#
# `assert` 문은 예외를 발생시키는 다른 방법입니다.
#
# 보통 **상태를 검증하는데 사용**되며 무조건 `AssertionError`가 발생합니다.
#
# ---
#
# **활용법**
#
# ```python
# assert Boolean expression, error message
#
# assert len([1, 2]) == 1, '길이가 1이 아닙니다.'
# ```
#
# ---
#
# 위의 검증식이 거짓일 경우를 발생합니다.
#
# 일반적으로 디버깅용도로 사용됩니다. [파이썬 문서](https://docs.python.org/ko/3/reference/simple_stmts.html#the-assert-statement)
#
# ```bash
# $ python code.py
# Traceback (most recent call last):
#   File "code.py", line 1, in <module>
#     assert len([1, 2]) == 1, '길이가 1이 아닙니다.'
# AssertionError: 길이가 1이 아닙니다.
#
# $ python -O code.py
#
# ```

# %%
assert 1 == 2, '1이랑 2는 같지 않아야 합니다'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 assert 1 == 2, '1이랑 2는 같지 않아야 합니다'
#
# AssertionError: 1이랑 2는 같지 않아야 합니다
