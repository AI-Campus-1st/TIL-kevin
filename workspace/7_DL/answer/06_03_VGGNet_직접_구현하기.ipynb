# %% [markdown]
# ### CUDA 버전 확인하기
#
# - !nvidia-smi
# - !nvcc --version
#
# 둘의 차이점은
# nvidia-smi는 해당 장치에서 설치 가능한 가장 높은 버전을 보여주고,
# nvcc --version은 현재 설치된 cuda 버전을 보여줌
#
# 출처 : https://stackoverflow.com/questions/9727688/how-to-get-the-cuda-version

# %%
gpu_info = !nvcc --version

# %%
gpu_info = '\n'.join(gpu_info)
print(gpu_info)
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2025 NVIDIA Corporation
# Built on Tue_May_27_02:24:01_Pacific_Daylight_Time_2025
# Cuda compilation tools, release 12.9, V12.9.86
# Build cuda_12.9.r12.9/compiler.36037853_0

# %%
# !nvidia-smi
# Out:
# Thu Sep 17 13:59:40 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 616.92                 KMD Version: 616.92        CUDA UMD Version: 13.4     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5060 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   56C    P0             13W /  105W |       0MiB /   8151MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# PyTorch 2.x 버전 설치
try:
    # 기본적으로 https://pytorch.kr/get-started/locally/ 에서
    # cuda 버전과 패키지매니저에 맞는 설치 명령어를 확인 가능
    # %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
    import torch
    print(torch.__version__)
except:
    pass
# Out:
# 2.14.0+cpu

# %% [markdown]
# ----------------------------------------------------------
#
# # VGGNet 직접 구현하기

# %%
# pytorch에서 사용할 함수들 호출하기
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 5
#       1 # pytorch에서 사용할 함수들 호출하기
#       2 import torch.nn as nn
#       3 import torch.nn.functional as F
#       4 import torch.optim as optim
# ----> 5 from torchvision import datasets, transforms
#       6 from torch.optim.lr_scheduler import StepLR
#
# File ~\anaconda3\envs\campus\Lib\site-packages\torchvision\__init__.py:8
#       5 # Don't re-order these, we need to load the _C_stable extension (done when importing
#       6 # .extension) before entering _meta_registrations.
#       7 from . import extension  # usort:skip  # noqa: F401
# ----> 8 from torchvision import (
#       9     _autograd_registrations,
#      10     _meta_registrations,
#      11     datasets,
#      12     io,
#      13     models,
#      14     ops,
#      15     transforms,
#      16     utils,
#      17 )  # usort:skip
#      19 try:
#      20     from .version import __version__  # noqa: F401
#
# File ~\anaconda3\envs\campus\Lib\site-packages\torchvision\_meta_registrations.py:163
#     153     torch._check(
#     154         grad.dtype == rois.dtype,
#     155         lambda: (
#    (...)    158         ),
#     159     )
#     160     return grad.new_empty((batch_size, channels, height, width))
# --> 163 @torch.library.register_fake("torchvision::nms")
#     164 def meta_nms(dets, scores, iou_threshold):
#     165     torch._check(dets.dim() == 2, lambda: f"boxes should be a 2d tensor, got {dets.dim()}D")
#     166     torch._check(dets.size(1) == 4, lambda: f"boxes should have 4 elements in dimension 1, got {dets.size(1)}")
#
# File ~\anaconda3\envs\campus\Lib\site-packages\torch\library.py:1271, in register_fake.<locals>.register(func)
#    1269 namespace, op_name = torch._library.utils.parse_namespace(op)
#    1270 use_lib = _library_for_registration(namespace, lib)
# -> 1271 use_lib._register_fake(
#    1272     op_name, func, _stacklevel=stacklevel + 1, allow_override=allow_override
#    1273 )
#    1274 return func
#
# File ~\anaconda3\envs\campus\Lib\site-packages\torch\library.py:354, in Library._register_fake(self, op_name, fn, _stacklevel, allow_override)
#     351 else:
#     352     func_to_register = fn
# --> 354 handle = entry.fake_impl.register(
#     355     func_to_register, source, lib=self, allow_override=allow_override
#     356 )
#     357 self._registration_handles.append(handle)
#
# File ~\anaconda3\envs\campus\Lib\site-packages\torch\_library\fake_impl.py:87, in FakeImplHolder.register(self, func, source, lib, allow_override)
#      85 meta_kernel = construct_meta_kernel(self.qualname, self)
#      86 try:
# ---> 87     lib.impl(self.qualname, meta_kernel, "Meta", allow_override=allow_override)
#      88 except Exception:
#      89     log.info(
#      90         "Failed to register fake_impl '%s':",
#      91         self.qualname,
#      92     )
#
# File ~\anaconda3\envs\campus\Lib\site-packages\torch\library.py:496, in Library.impl(self, op_name, fn, dispatch_key, with_keyset, allow_override)
#     490         dispatcher_op_name = f"{self.ns}::{dispatcher_op_name}"
#     492     # Internally, we shouldn't be registering meta kernels for any operators that
#     493     # have CompositeImplicitAutograd kernels.
#     494     # Instead, we should be letting those decompositions run, and writing meta kernels
#     495     # only for the base operators.
# --> 496     if torch._C._dispatch_has_kernel_for_dispatch_key(
#     497         dispatcher_op_name, "CompositeImplicitAutograd"
#     498     ):
#     499         raise RuntimeError(
#     500             f"We should not register a meta kernel directly to the operator '{name}',"
#     501             " because it has a CompositeImplicitAutograd kernel in core."
#     502             " Instead we should let the operator decompose, and ensure that we have meta kernels"
#     503             " for the base ops that it decomposes into."
#     504         )
#     506 if self.m is None:
#
# RuntimeError: operator torchvision::nms does not exist

# %%
# 데이터가 상당히 크기 때문에 시간이 좀 소요됨
transform = transforms.Compose([
    transforms.Resize(72),
    transforms.RandomCrop(56),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5 ), (0.5, 0.5, 0.5 )),
])

train_dataset = datasets.STL10(root='./data', split='train', download=True, transform=transform)
# train_dataset = datasets.MNIST('./data', train=True, download=True, transform=transform)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=256, shuffle=True)

test_dataset = datasets.STL10(root='./data', split='test', download=True, transform=transform)
# test_dataset = datasets.MNIST('./data', train=False, download=True, transform=transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=256, shuffle=False)

# %%
class VGGNet11(nn.Module):

    def __init__(self, num_classes=10):
        super(VGGNet11, self).__init__()
        # 3 x 56 x 56
        self.convnet = nn.Sequential(
            # 여기에 CNN 모델을 구현해주세요.
            nn.Conv2d(3, 64, 3, stride=1, padding=1), # 64 x 56 x 56
            nn.ReLU(),
            nn.MaxPool2d(2), # 64 x 28 x 28

            nn.Conv2d(64, 128, 3, stride=1, padding=1), # 128 x 28 x 28
            nn.ReLU(),
            nn.MaxPool2d(2), # 128 x 14 x 14

            nn.Conv2d(128, 256, 3, stride=1, padding=1), # 256 x 14 x 14
            nn.ReLU(),
            nn.Conv2d(256, 256, 3, stride=1, padding=1), # 256 x 14 x 14
            nn.ReLU(),
            nn.MaxPool2d(2), # 256 x 7 x 7

            nn.Conv2d(256, 512, 3, stride=1, padding=1), # 512 x 7 x 7
            nn.ReLU(),
            nn.Conv2d(512, 512, 3, stride=1, padding=1), # 512 x 7 x 7
            nn.ReLU(),
            nn.MaxPool2d(2), # 512 x 3 x 3

            nn.Conv2d(512, 512, 3, stride=1, padding=1), # 512 x 3 x 3
            nn.ReLU(),
            nn.Conv2d(512, 512, 3, stride=1, padding=1), # 512 x 3 x 3
            nn.ReLU(),
            nn.MaxPool2d(2), # 512 x 1 x 1
        )

        self.fclayer = nn.Sequential(
            # 여기에 FC 모델을 구현해주세요.
            nn.Linear(512, 4096),
            nn.ReLU(),
            nn.Linear(4096, 4096),
            nn.ReLU(),
            nn.Linear(4096, num_classes)
        )

    def forward(self, x):
        x = self.convnet(x)
        x = torch.flatten(x, 1)
        output = self.fclayer(x)
        return output

# %%
model = VGGNet11(num_classes=10)

# %%
# %pip install torchinfo
from torchinfo import summary
summary(model)
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# VGGNet11                                 --
# ├─Sequential: 1-1                        --
# │    └─Conv2d: 2-1                       1,792
# │    └─ReLU: 2-2                         --
# │    └─MaxPool2d: 2-3                    --
# │    └─Conv2d: 2-4                       73,856
# │    └─ReLU: 2-5                         --
# │    └─MaxPool2d: 2-6                    --
# │    └─Conv2d: 2-7                       295,168
# │    └─ReLU: 2-8                         --
# │    └─Conv2d: 2-9                       590,080
# │    └─ReLU: 2-10                        --
# │    └─MaxPool2d: 2-11                   --
# │    └─Conv2d: 2-12                      1,180,160
# │    └─ReLU: 2-13                        --
# │    └─Conv2d: 2-14                      2,359,808
# │    └─ReLU: 2-15                        --
# │    └─MaxPool2d: 2-16                   --
# │    └─Conv2d: 2-17                      2,359,808
# │    └─ReLU: 2-18                        --
# │    └─Conv2d: 2-19                      2,359,808
# │    └─ReLU: 2-20                        --
# │    └─MaxPool2d: 2-21                   --
# ├─Sequential: 1-2                        --
# │    └─Linear: 2-22                      2,101,248
# │    └─ReLU: 2-23                        --
# │    └─Linear: 2-24                      16,781,312
# │    └─ReLU: 2-25                        --
# │    └─Linear: 2-26                      40,970
# =================================================================
# Total params: 28,144,010
# Trainable params: 28,144,010
# Non-trainable params: 0
# =================================================================

# %%
# 학습을 위한 설정
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model.to(device)

criterion = nn.CrossEntropyLoss().cuda()
optimizer = optim.Adam(model.parameters(),lr=1e-5)
scheduler = StepLR(optimizer, step_size=30, gamma=0.1)

# %%
# 모델 학습
epochs = 40
dry_run = False # 1 배치만 훈련

for epoch in range(1, epochs+1):
    # 학습
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 10 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.detach().cpu().item()))
            if dry_run:
                break

    # 테스트
    model.eval()
    test_loss = 0
    correct = 0

    for data, target in test_loader:
        data, target = data.to(device), target.to(device)
        with torch.no_grad():
            output = model(data)
        test_loss += criterion(output, target).detach().cpu().item()
        pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
        correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

    scheduler.step()

# %%
for name, param in model.named_parameters():
    print(name)
    print(param)
    break
